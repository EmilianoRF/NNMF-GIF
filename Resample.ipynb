# %%
import numpy as np
from scipy.io import wavfile
import IPython.display as ipd
from scipy import signal
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

wave_duration = 3
sample_rate = 100
n_sample_rate = 50
freq = 2
q = int(sample_rate/n_sample_rate)

samples = wave_duration*sample_rate
samples_decimated = int(samples/q)
x = np.linspace(0, wave_duration, samples, endpoint=False)

y = np.cos(x*np.pi*x*2)

#ydem = signal.decimate(y, q)
#ydem = signal.resample(y, 100)
#xnew = np.linspace(0, wave_duration, 100, endpoint=False)

fig,ax = plt.subplots(figsize=(15,5))
ax.plot(x, y, '.-')
ax.plot(xnew, ydem, 'o-')
ax.set_xlabel('Time, Seconds')
ax.legend(['data', 'decimated'], loc='best');
